# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import matplotlib

# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12 = pd.read_table("Euro_2012_stats_TEAM.csv" , sep = ",")
euro12
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8404\106855099.py in <module>
# ----> 1 euro12 = pd.read_table("Euro_2012_stats_TEAM.csv" , sep = ",")
#       2 euro12
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12.Team.nunique()
# Out:
# 16

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
euro12.columns.shape
# Out:
# (35,)

# %% [markdown]
# # Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
euro12[["Team","Yellow Cards","Red Cards"]]
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
euro12[["Team" , "Red Cards"]].sort_values("Red Cards")
# Out:
#                    Team  Red Cards
# 0               Croatia          0
# 1        Czech Republic          0
# 2               Denmark          0
# 3               England          0
# 4                France          0
# 5               Germany          0
# 7                 Italy          0
# 8           Netherlands          0
# 10             Portugal          0
# 12               Russia          0
# 13                Spain          0
# 14               Sweden          0
# 15              Ukraine          0
# 6                Greece          1
# 9                Poland          1
# 11  Republic of Ireland          1

# %%
euro12[["Team" , "Yellow Cards"]].sort_values("Yellow Cards")
# Out:
#                    Team  Yellow Cards
# 2               Denmark             4
# 5               Germany             4
# 3               England             5
# 8           Netherlands             5
# 15              Ukraine             5
# 4                France             6
# 11  Republic of Ireland             6
# 12               Russia             6
# 1        Czech Republic             7
# 9                Poland             7
# 14               Sweden             7
# 0               Croatia             9
# 6                Greece             9
# 13                Spain            11
# 10             Portugal            12
# 7                 Italy            16

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro12.rename(columns= {'Yellow Cards': "Yellow_Cards"},inplace = True)
euro12.groupby('Team')[['Yellow_Cards']].mean()
# Out:
#                      Yellow_Cards
# Team
# Croatia                       9.0
# Czech Republic                7.0
# Denmark                       4.0
# England                       5.0
# France                        6.0
# Germany                       4.0
# Greece                        9.0
# Italy                        16.0
# Netherlands                   5.0
# Poland                        7.0
# Portugal                     12.0
# Republic of Ireland           6.0
# Russia                        6.0
# Spain                        11.0
# Sweden                        7.0
# Ukraine                       5.0

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12.Goals > 6]["Team"]
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
euro12[euro12.Team.str.startswith("G")]["Team"]
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12.iloc[:    ,    :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.rename(columns= {'Shooting Accuracy': "Shooting_Accuracy"},inplace = True)
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting_Accuracy']]
# Out:
#        Team Shooting_Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
